# %%
import warnings
warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd

import geopandas as gpd
from shapely.geometry import shape

import matplotlib.pyplot as plt
import seaborn as sns
from shapely.geometry import Point
import plotly.figure_factory as ff
import plotly.express as px

from urllib.parse import urlencode
import urllib.request, json 

import requests

# %%
#Get the first 50 records
api_key = '0CAOsJ725cCRmvjfewQeFpPQbg_fuGn8qF_yrIET66U8qA7H25WkCXAPznZp0yJR8ZEt1OfSmZN5ejacRpjVzdxsyqTGcULuVxcXAihtpju1zDuhu_QEmcHcdn6QYXYx'
headers = {'Authorization':'Bearer %s'% api_key}
url = 'https://api.yelp.com/v3/businesses/search'
params1 = {'categories':'Restaurants','location':"Bronx", 'limit':"50"}
req1 = requests.get(url, params = params1, headers = headers)
reqs1 = json.loads(req1.text)

# %%
df1=pd.DataFrame.from_dict(reqs1['businesses'])

# %%
#Use for loop to acquire the 50-1000 records

def search_res(set_num): 
# This function launches the request for all restaurant location endpoints in New York, NY.
    api_key = '0CAOsJ725cCRmvjfewQeFpPQbg_fuGn8qF_yrIET66U8qA7H25WkCXAPznZp0yJR8ZEt1OfSmZN5ejacRpjVzdxsyqTGcULuVxcXAihtpju1zDuhu_QEmcHcdn6QYXYx'
    url = 'https://api.yelp.com/v3/businesses/search'
    headers = {'Authorization': 'Bearer %s'% api_key}
    url_params = { #parameters passed to the API
    "categoris":"Restaurants",
    "location":"Bronx",
    'offset': offset_num, # We are going to iterate the offset
     "limit":50 # Maximum return of results per request (ref: API documentation).
     }

    response = requests.get(url, headers=headers, params=url_params)
    return response.json() # Returns a JSON.


if __name__ == "__main__":
    for offset_num in np.arange(50,1000,50) : 
        try:
            output_json = search_res(offset_num) # Executing the function defined above.
            # print(offset_num) # Making sure each offset iteration is running
            # print(output_json) # If you wanna check the JSON for each iteration
            if offset_num == 50:
                df_second = pd.DataFrame.from_dict(output_json['businesses'])
                df1 = df1.append(df_second)
            else:
                df_third = pd.DataFrame.from_dict(output_json['businesses'])
                df1 = df1.append(df_third)
        except AttributeError:
            print("error at ", offset_num) # Helpful for debugging purposes
            
    df1.to_csv("../Data/0413_Yelp_Bronx.csv", index = False)

# %%
MR = pd.read_csv('../Data/0413_Yelp_Bronx.csv')
MR.head(5)
# Out:
#                        id                            alias  \
# 0  b6jOwyX4iaagw8YjXqq1sA         antonios-trattoria-bronx
# 1  HeR2gHJbP5CN69UsVCtMGg  new-york-botanical-garden-bronx
# 2  I2XhY76Mmc6yTg-aSBBHfQ                  bronx-zoo-bronx
# 3  2iqsjuh8Mpm_3p6s-G9zkQ       taqueria-tlaxcalli-bronx-3
# 4  tLZfepIfSf0a80zHQTbTGQ   trattoria-zero-otto-nove-bronx
#
#                         name  \
# 0        Antonio's Trattoria
# 1  New York Botanical Garden
# 2                  Bronx Zoo
# 3         Taqueria Tlaxcalli
# 4   Trattoria Zero Otto Nove
#
#                                            image_url  is_closed  \
# 0  https://s3-media3.fl.yelpcdn.com/bphoto/2JkIBH...      False
# 1  https://s3-media3.fl.yelpcdn.com/bphoto/Cv-mpt...      False
# 2  https://s3-media4.fl.yelpcdn.com/bphoto/d4qI_g...      False
# 3  https://s3-media4.fl.yelpcdn.com/bphoto/oGsoEK...      False
# 4  https://s3-media2.fl.yelpcdn.com/bphoto/lvgheh...      False
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/antonios-trattoria-br...           910
# 1  https://www.yelp.com/biz/new-york-botanical-ga...           829
# 2  https://www.yelp.com/biz/bronx-zoo-bronx?adjus...          1182
# 3  https://www.yelp.com/biz/taqueria-tlaxcalli-br...           674
# 4  https://www.yelp.com/biz/trattoria-zero-otto-n...           820
#
#                                           categories  rating  \
# 0  [{'alias': 'italian', 'title': 'Italian'}, {'a...     4.5
# 1  [{'alias': 'gardens', 'title': 'Botanical Gard...     4.5
# 2               [{'alias': 'zoos', 'title': 'Zoos'}]     4.0
# 3         [{'alias': 'mexican', 'title': 'Mexican'}]     4.5
# 4  [{'alias': 'italian', 'title': 'Italian'}, {'a...     4.0
#
#                                          coordinates            transactions  \
# 0   {'latitude': 40.854131, 'longitude': -73.886601}  ['pickup', 'delivery']
# 1  {'latitude': 40.8624081105702, 'longitude': -7...                      []
# 2  {'latitude': 40.8486241952854, 'longitude': -7...                      []
# 3    {'latitude': 40.83624, 'longitude': -73.854962}  ['pickup', 'delivery']
# 4   {'latitude': 40.854779, 'longitude': -73.888474}            ['delivery']
#
#   price                                           location         phone  \
# 0    $$  {'address1': '2370 Belmont Ave', 'address2': N...  1.718734e+10
# 1   NaN  {'address1': '2900 Southern Blvd', 'address2':...  1.718818e+10
# 2   NaN  {'address1': '2300 Southern Blvd', 'address2':...  1.718221e+10
# 3    $$  {'address1': '2103 Starling Ave', 'address2': ...  1.347851e+10
# 4    $$  {'address1': '2357 Arthur Ave', 'address2': ''...  1.718220e+10
#
#     display_phone     distance
# 0  (718) 733-6630  1297.605191
# 1  (718) 817-8700  1225.978878
# 2  (718) 220-5100  1021.078432
# 3  (347) 851-3085  2236.452704
# 4  (718) 220-1027  1465.542235

# %%
MR['coordinates']=MR['coordinates'].astype('str')
MR['coordinates']=MR['coordinates'].map(eval)
df_coord = MR['coordinates'].apply(pd.Series)

# %%
MR2 = pd.concat([MR.drop(['coordinates'],axis=1),df_coord],axis=1)
MR2.head(2)
# Out:
#                        id                            alias  \
# 0  b6jOwyX4iaagw8YjXqq1sA         antonios-trattoria-bronx
# 1  HeR2gHJbP5CN69UsVCtMGg  new-york-botanical-garden-bronx
#
#                         name  \
# 0        Antonio's Trattoria
# 1  New York Botanical Garden
#
#                                            image_url  is_closed  \
# 0  https://s3-media3.fl.yelpcdn.com/bphoto/2JkIBH...      False
# 1  https://s3-media3.fl.yelpcdn.com/bphoto/Cv-mpt...      False
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/antonios-trattoria-br...           910
# 1  https://www.yelp.com/biz/new-york-botanical-ga...           829
#
#                                           categories  rating  \
# 0  [{'alias': 'italian', 'title': 'Italian'}, {'a...     4.5
# 1  [{'alias': 'gardens', 'title': 'Botanical Gard...     4.5
#
#              transactions price  \
# 0  ['pickup', 'delivery']    $$
# 1                      []   NaN
#
#                                             location         phone  \
# 0  {'address1': '2370 Belmont Ave', 'address2': N...  1.718734e+10
# 1  {'address1': '2900 Southern Blvd', 'address2':...  1.718818e+10
#
#     display_phone     distance   latitude  longitude
# 0  (718) 733-6630  1297.605191  40.854131 -73.886601
# 1  (718) 817-8700  1225.978878  40.862408 -73.876919

# %%
MR['categories']=MR['categories'].astype('str')
MR['categories']=MR['categories'].map(eval)
df_cate = MR['categories'].apply(pd.Series)

df_cate.head(2)
# Out:
#                                                    0  \
# 0           {'alias': 'italian', 'title': 'Italian'}
# 1  {'alias': 'gardens', 'title': 'Botanical Garde...
#
#                                       1  \
# 0  {'alias': 'pizza', 'title': 'Pizza'}
# 1                                   NaN
#
#                                             2
# 0  {'alias': 'desserts', 'title': 'Desserts'}
# 1                                         NaN

# %%
MR['location']=MR['location'].astype('str')
MR['location']=MR['location'].map(eval)
df_loc = MR['location'].apply(pd.Series)
df_loc2 = df_loc.drop(['address2','address3'],axis=1)
df_loc2.head(2)
# Out:
#              address1   city zip_code country state  \
# 0    2370 Belmont Ave  Bronx    10458      US    NY
# 1  2900 Southern Blvd  Bronx    10458      US    NY
#
#                          display_address
# 0    [2370 Belmont Ave, Bronx, NY 10458]
# 1  [2900 Southern Blvd, Bronx, NY 10458]

# %%
df_cate2 = df_cate[0].apply(pd.Series)
df_cate2.head(2)
# Out:
#      alias              title
# 0  italian            Italian
# 1  gardens  Botanical Gardens

# %%
MR3 = pd.concat([MR2.drop(['categories','alias','location'],axis=1),df_loc2,df_cate2],axis=1)
MR3.head(2)
# Out:
#                        id                       name  \
# 0  b6jOwyX4iaagw8YjXqq1sA        Antonio's Trattoria
# 1  HeR2gHJbP5CN69UsVCtMGg  New York Botanical Garden
#
#                                            image_url  is_closed  \
# 0  https://s3-media3.fl.yelpcdn.com/bphoto/2JkIBH...      False
# 1  https://s3-media3.fl.yelpcdn.com/bphoto/Cv-mpt...      False
#
#                                                  url  review_count  rating  \
# 0  https://www.yelp.com/biz/antonios-trattoria-br...           910     4.5
# 1  https://www.yelp.com/biz/new-york-botanical-ga...           829     4.5
#
#              transactions price         phone  ...   latitude  longitude  \
# 0  ['pickup', 'delivery']    $$  1.718734e+10  ...  40.854131 -73.886601
# 1                      []   NaN  1.718818e+10  ...  40.862408 -73.876919
#
#              address1   city zip_code country state  \
# 0    2370 Belmont Ave  Bronx    10458      US    NY
# 1  2900 Southern Blvd  Bronx    10458      US    NY
#
#                          display_address    alias              title
# 0    [2370 Belmont Ave, Bronx, NY 10458]  italian            Italian
# 1  [2900 Southern Blvd, Bronx, NY 10458]  gardens  Botanical Gardens
#
# [2 rows x 22 columns]

# %%
df_MR = MR3[['name','review_count','rating','transactions','price','latitude','longitude','alias','address1','city','zip_code','display_address']]
df_MR.head(2)
# Out:
#                         name  review_count  rating            transactions  \
# 0        Antonio's Trattoria           910     4.5  ['pickup', 'delivery']
# 1  New York Botanical Garden           829     4.5                      []
#
#   price   latitude  longitude    alias            address1   city zip_code  \
# 0    $$  40.854131 -73.886601  italian    2370 Belmont Ave  Bronx    10458
# 1   NaN  40.862408 -73.876919  gardens  2900 Southern Blvd  Bronx    10458
#
#                          display_address
# 0    [2370 Belmont Ave, Bronx, NY 10458]
# 1  [2900 Southern Blvd, Bronx, NY 10458]

# %%
df_MR.head(10)
df_MR.to_csv('../Data/0413_Yelp_Bronx.csv')

# %%
access_token = 'pk.eyJ1IjoibWVuZ3FpMTAwNyIsImEiOiJja2k2YTlqMGQwdTNtMndudzBycjIyanQyIn0.uKaRw_TZaJq-5lCDNLhUOg'
px.set_mapbox_access_token(access_token)

# %%
fig = px.scatter_mapbox(df_MR,
                    lat='latitude',
                    lon='longitude',
                    color='rating',
                    color_discrete_sequence=px.colors.qualitative.Plotly,
                    mapbox_style='dark')

fig.update_layout(autosize=False,
                 width=1000,
                 height=800)


fig.update_layout(mapbox_zoom=11, 
                  mapbox_center = {"lat": 40.765, "lon": -73.94})
# fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})

fig.show()
