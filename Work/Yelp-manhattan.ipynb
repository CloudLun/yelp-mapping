# %%
import warnings
warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd

import geopandas as gpd
from shapely.geometry import shape

import matplotlib.pyplot as plt
import seaborn as sns
from shapely.geometry import Point
import plotly.figure_factory as ff
import plotly.express as px

from urllib.parse import urlencode
import urllib.request, json 

import requests

# %%
#Get the first 50 records
api_key = '0CAOsJ725cCRmvjfewQeFpPQbg_fuGn8qF_yrIET66U8qA7H25WkCXAPznZp0yJR8ZEt1OfSmZN5ejacRpjVzdxsyqTGcULuVxcXAihtpju1zDuhu_QEmcHcdn6QYXYx'
headers = {'Authorization':'Bearer %s'% api_key}
url = 'https://api.yelp.com/v3/businesses/search'
params1 = {'categories':'Restaurants','location':"Manahattan", 'limit':"50"}
req1 = requests.get(url, params = params1, headers = headers)
reqs1 = json.loads(req1.text)

# %%
df1=pd.DataFrame.from_dict(reqs1['businesses'])

# %%
#Use for loop to acquire the 50-1000 records

def search_res(set_num): 
# This function launches the request for all restaurant location endpoints in New York, NY.
    api_key = '0CAOsJ725cCRmvjfewQeFpPQbg_fuGn8qF_yrIET66U8qA7H25WkCXAPznZp0yJR8ZEt1OfSmZN5ejacRpjVzdxsyqTGcULuVxcXAihtpju1zDuhu_QEmcHcdn6QYXYx'
    url = 'https://api.yelp.com/v3/businesses/search'
    headers = {'Authorization': 'Bearer %s'% api_key}
    url_params = { #parameters passed to the API
    "categoris":"Restaurants",
    "location":"Manahattan",
    'offset': offset_num, # We are going to iterate the offset
     "limit":50 # Maximum return of results per request (ref: API documentation).
     }

    response = requests.get(url, headers=headers, params=url_params)
    return response.json() # Returns a JSON.


if __name__ == "__main__":
    for offset_num in np.arange(50,1000,50) : 
        try:
            output_json = search_res(offset_num) # Executing the function defined above.
            # print(offset_num) # Making sure each offset iteration is running
            # print(output_json) # If you wanna check the JSON for each iteration
            if offset_num == 50:
                df_second = pd.DataFrame.from_dict(output_json['businesses'])
                df1 = df1.append(df_second)
            else:
                df_third = pd.DataFrame.from_dict(output_json['businesses'])
                df1 = df1.append(df_third)
        except AttributeError:
            print("error at ", offset_num) # Helpful for debugging purposes
            
    df1.to_csv("../Data/0413_Yelp_Manhattan.csv", index = False)

# %%
MR = pd.read_csv('../Data/0413_Yelp_Manhattan.csv')
MR.head(5)
# Out:
#                        id                              alias  \
# 0  xEnNFXtMLDF5kZDxfaCJgA          the-halal-guys-new-york-2
# 1  H4jJ7XB3CetIr1pg56CczQ             levain-bakery-new-york
# 2  KFnr0CGsHQ2ABFHbLNtobQ  central-park-conservancy-new-york
# 3  WHRHK3S1mQc3PmhwsGRvbw          bibble-and-sip-new-york-2
# 4  A_YpTLbAlEqeLVSs9bxbEA         club-a-steakhouse-new-york
#
#                        name  \
# 0            The Halal Guys
# 1             Levain Bakery
# 2  Central Park Conservancy
# 3              Bibble & Sip
# 4         Club A Steakhouse
#
#                                            image_url  is_closed  \
# 0  https://s3-media2.fl.yelpcdn.com/bphoto/pqcdqG...      False
# 1  https://s3-media3.fl.yelpcdn.com/bphoto/hCp7TJ...      False
# 2  https://s3-media2.fl.yelpcdn.com/bphoto/2QeE4Z...      False
# 3  https://s3-media1.fl.yelpcdn.com/bphoto/qVGATB...      False
# 4  https://s3-media3.fl.yelpcdn.com/bphoto/btpo6T...      False
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/the-halal-guys-new-yo...          9806
# 1  https://www.yelp.com/biz/levain-bakery-new-yor...          8794
# 2  https://www.yelp.com/biz/central-park-conserva...          2621
# 3  https://www.yelp.com/biz/bibble-and-sip-new-yo...          5202
# 4  https://www.yelp.com/biz/club-a-steakhouse-new...          3074
#
#                                           categories  rating  \
# 0  [{'alias': 'foodstands', 'title': 'Food Stands...     4.0
# 1       [{'alias': 'bakeries', 'title': 'Bakeries'}]     4.5
# 2             [{'alias': 'parks', 'title': 'Parks'}]     5.0
# 3  [{'alias': 'coffee', 'title': 'Coffee & Tea'},...     4.5
# 4       [{'alias': 'steak', 'title': 'Steakhouses'}]     4.5
#
#                                          coordinates            transactions  \
# 0   {'latitude': 40.761861, 'longitude': -73.979306}  ['pickup', 'delivery']
# 1   {'latitude': 40.779961, 'longitude': -73.980299}                      []
# 2   {'latitude': 40.764266, 'longitude': -73.971656}                      []
# 3  {'latitude': 40.7628355, 'longitude': -73.9851...  ['pickup', 'delivery']
# 4     {'latitude': 40.76006, 'longitude': -73.96557}  ['pickup', 'delivery']
#
#   price                                           location         phone  \
# 0     $  {'address1': 'W 53rd Street And 6th Ave', 'add...  1.347527e+10
# 1    $$  {'address1': '167 W 74th St', 'address2': '', ...  1.917464e+10
# 2   NaN  {'address1': '14 E 60th St', 'address2': '', '...  1.212311e+10
# 3    $$  {'address1': '253 W 51st St', 'address2': '', ...  1.646650e+10
# 4   $$$  {'address1': '240 E 58th St', 'address2': '', ...  1.212688e+10
#
#     display_phone     distance
# 0  (347) 527-1505   872.399754
# 1  (917) 464-3769  2481.526257
# 2  (212) 310-6600   599.089307
# 3  (646) 649-5116  1375.988854
# 4  (212) 688-4190   350.236188

# %%
MR['coordinates']=MR['coordinates'].astype('str')
MR['coordinates']=MR['coordinates'].map(eval)
df_coord = MR['coordinates'].apply(pd.Series)

# %%
MR2 = pd.concat([MR.drop(['coordinates'],axis=1),df_coord],axis=1)
MR2.head(2)
# Out:
#                        id                      alias            name  \
# 0  xEnNFXtMLDF5kZDxfaCJgA  the-halal-guys-new-york-2  The Halal Guys
# 1  H4jJ7XB3CetIr1pg56CczQ     levain-bakery-new-york   Levain Bakery
#
#                                            image_url  is_closed  \
# 0  https://s3-media2.fl.yelpcdn.com/bphoto/pqcdqG...      False
# 1  https://s3-media3.fl.yelpcdn.com/bphoto/hCp7TJ...      False
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/the-halal-guys-new-yo...          9806
# 1  https://www.yelp.com/biz/levain-bakery-new-yor...          8794
#
#                                           categories  rating  \
# 0  [{'alias': 'foodstands', 'title': 'Food Stands...     4.0
# 1       [{'alias': 'bakeries', 'title': 'Bakeries'}]     4.5
#
#              transactions price  \
# 0  ['pickup', 'delivery']     $
# 1                      []    $$
#
#                                             location         phone  \
# 0  {'address1': 'W 53rd Street And 6th Ave', 'add...  1.347527e+10
# 1  {'address1': '167 W 74th St', 'address2': '', ...  1.917464e+10
#
#     display_phone     distance   latitude  longitude
# 0  (347) 527-1505   872.399754  40.761861 -73.979306
# 1  (917) 464-3769  2481.526257  40.779961 -73.980299

# %%
MR['categories']=MR['categories'].astype('str')
MR['categories']=MR['categories'].map(eval)
df_cate = MR['categories'].apply(pd.Series)

df_cate.head(2)
# Out:
#                                                  0  \
# 0  {'alias': 'foodstands', 'title': 'Food Stands'}
# 1       {'alias': 'bakeries', 'title': 'Bakeries'}
#
#                                                    1  \
# 0  {'alias': 'mideastern', 'title': 'Middle Easte...
# 1                                                NaN
#
#                                       2
# 0  {'alias': 'halal', 'title': 'Halal'}
# 1                                   NaN

# %%
MR['location']=MR['location'].astype('str')
MR['location']=MR['location'].map(eval)
df_loc = MR['location'].apply(pd.Series)
df_loc2 = df_loc.drop(['address2','address3'],axis=1)
df_loc2.head(2)
# Out:
#                     address1      city zip_code country state  \
# 0  W 53rd Street And 6th Ave  New York    10019      US    NY
# 1              167 W 74th St  New York    10023      US    NY
#
#                                    display_address
# 0  [W 53rd Street And 6th Ave, New York, NY 10019]
# 1              [167 W 74th St, New York, NY 10023]

# %%
df_cate2 = df_cate[0].apply(pd.Series)
df_cate2.head(2)
# Out:
#         alias        title
# 0  foodstands  Food Stands
# 1    bakeries     Bakeries

# %%
MR3 = pd.concat([MR2.drop(['categories','alias','location'],axis=1),df_loc2,df_cate2],axis=1)
MR3.head(2)
# Out:
#                        id            name  \
# 0  xEnNFXtMLDF5kZDxfaCJgA  The Halal Guys
# 1  H4jJ7XB3CetIr1pg56CczQ   Levain Bakery
#
#                                            image_url  is_closed  \
# 0  https://s3-media2.fl.yelpcdn.com/bphoto/pqcdqG...      False
# 1  https://s3-media3.fl.yelpcdn.com/bphoto/hCp7TJ...      False
#
#                                                  url  review_count  rating  \
# 0  https://www.yelp.com/biz/the-halal-guys-new-yo...          9806     4.0
# 1  https://www.yelp.com/biz/levain-bakery-new-yor...          8794     4.5
#
#              transactions price         phone  ...   latitude  longitude  \
# 0  ['pickup', 'delivery']     $  1.347527e+10  ...  40.761861 -73.979306
# 1                      []    $$  1.917464e+10  ...  40.779961 -73.980299
#
#                     address1      city zip_code country state  \
# 0  W 53rd Street And 6th Ave  New York    10019      US    NY
# 1              167 W 74th St  New York    10023      US    NY
#
#                                    display_address       alias        title
# 0  [W 53rd Street And 6th Ave, New York, NY 10019]  foodstands  Food Stands
# 1              [167 W 74th St, New York, NY 10023]    bakeries     Bakeries
#
# [2 rows x 22 columns]

# %%
df_MR = MR3[['name','review_count','rating','transactions','price','latitude','longitude','alias','address1','city','zip_code','display_address']]
df_MR.head(2)
# Out:
#              name  review_count  rating            transactions price  \
# 0  The Halal Guys          9806     4.0  ['pickup', 'delivery']     $
# 1   Levain Bakery          8794     4.5                      []    $$
#
#     latitude  longitude       alias                   address1      city  \
# 0  40.761861 -73.979306  foodstands  W 53rd Street And 6th Ave  New York
# 1  40.779961 -73.980299    bakeries              167 W 74th St  New York
#
#   zip_code                                  display_address
# 0    10019  [W 53rd Street And 6th Ave, New York, NY 10019]
# 1    10023              [167 W 74th St, New York, NY 10023]

# %%
df_MR.head(10)
df_MR.to_csv('../Data/0413_Yelp_Manhattan.csv')

# %%
access_token = 'pk.eyJ1IjoibWVuZ3FpMTAwNyIsImEiOiJja2k2YTlqMGQwdTNtMndudzBycjIyanQyIn0.uKaRw_TZaJq-5lCDNLhUOg'
px.set_mapbox_access_token(access_token)

# %%
fig = px.scatter_mapbox(df_MR,
                    lat='latitude',
                    lon='longitude',
                    color='rating',
                    color_discrete_sequence=px.colors.qualitative.Plotly,
                    mapbox_style='dark')

fig.update_layout(autosize=False,
                 width=1000,
                 height=800)


fig.update_layout(mapbox_zoom=11, 
                  mapbox_center = {"lat": 40.765, "lon": -73.94})
# fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})

fig.show()
